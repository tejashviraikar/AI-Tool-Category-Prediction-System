# %%
pip install pandas numpy matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\user1\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\user1\anaconda3\lib\site-packages (2.2.5)
# Requirement already satisfied: matplotlib in c:\users\user1\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: seaborn in c:\users\user1\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user1\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user1\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user1\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\user1\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load dataset
file_path = "AI Tools Dataset.csv"   
df = pd.read_csv(file_path)

# %%
# Display first 5 rows
print("First 5 rows of dataset:")
print(df.head())
# Out:
# First 5 rows of dataset:
#                 Name                    Category  \
# 0            ChatGPT   Communication And Support
# 1             Claude   Operations And Management
# 2      Google Gemini     Ai And Machine Learning
# 3  Microsoft Copilot  Technology And Development
# 4              LLaMA     Ai And Machine Learning
#
#                                  Primary Task  Year Founded  \
# 0  Automated conversational customer service.        2022.0
# 1                             Task automation        2023.0
# 2                       Large Language Models        2023.0
# 3                    Automated conversational        2023.0
# 4                       Large Language Models        2022.0
#
#                                    Short Description        Country  \
# 0  ChatGPT is an advanced AI language model by Op...        Estonia
# 1  Automated assistant handles tasks and talks na...  United States
# 2  Google Gemini is Google DeepMind’s next-genera...            NaN
# 3  Microsoft Copilot is an AI-powered assistant i...            NaN
# 4  LLaMA is Meta’s family of large language model...          India
#
#                             industry  \
# 0  information technology & services
# 1                           research
# 2                                NaN
# 3                                NaN
# 4  information technology & services
#
#                                             Website Website Status
# 0            https://chatgpt.com?ref=aitoolbuzz.com         Active
# 1             https://claude.ai/?ref=aitoolbuzz.com         Active
# 2      https://gemini.google.com?ref=aitoolbuzz.com         Active
# 3  https://copilot.microsoft.com?ref=aitoolbuzz.com         Active
# 4          https://www.llama.com?ref=aitoolbuzz.com         Active

# %%
# Dataset shape
print("\nDataset Shape (Rows, Columns):")
print(df.shape)
# Out:
# Dataset Shape (Rows, Columns):
# (16762, 9)

# %%
# Column names
print("\nColumn Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['Name', 'Category', 'Primary Task', 'Year Founded', 'Short Description',
#        'Country', 'industry', 'Website', 'Website Status'],
#       dtype='object')

# %%
# Dataset info
print("\nDataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16762 entries, 0 to 16761
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               16762 non-null  object
#  1   Category           16762 non-null  object
#  2   Primary Task       16762 non-null  object
#  3   Year Founded       5831 non-null   float64
#  4   Short Description  16232 non-null  object
#  5   Country            6628 non-null   object
#  6   industry           7827 non-null   object
#  7   Website            16762 non-null  object
#  8   Website Status     16735 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 1.2+ MB
# None

# %%
# Check missing values
print("\nMissing Values Count:")
print(df.isnull().sum())
# Out:
# Missing Values Count:
# Name                     0
# Category                 0
# Primary Task             0
# Year Founded         10931
# Short Description      530
# Country              10134
# industry              8935
# Website                  0
# Website Status          27
# dtype: int64

# %%
# Save cleaned dataset copy
df.to_csv("AI_tools_collected_dataset.csv", index=False)

print("\nDataset successfully saved as collected_dataset.csv")
# Out:
# Dataset successfully saved as collected_dataset.csv
